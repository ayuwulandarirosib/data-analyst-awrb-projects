# %% [markdown]
# <div style="border:solid black 2px; padding: 20px">
# <div class="alert alert-success">
#
# # Interaction and Retention Strategies Analysis through Digitizing Customer Profiles by awrb
#
#
# </div>

# %% [markdown]
# # Table of Contents: <a id='tableofcontents'></a>
#
#     - 1. Introduction
#         - 1.1 Goal
#         - 1.2 Stages
#     - 2. Data Overview and Preprocessing
#         - 2.1 Data Overview Elaboration
#         - 2.2 Rectifying Columns Names
#         - 2.3 Ensuring the Data Quality
#         - 2.4 Ensuring for Data Type, Array Form, Missing Values, Duplicate Data
#     - 3. Data Processing
#         - 3.1 Taking a look at the dataset, are there any missing features?
#         - 3.2 Seeing the average feature value in two groups.
#         - 3.3 Creating a histogram and feature distribution for those who left (churn) as well as those who stayed.
#         - 3.4 Creating a correlation matrix and display of the results.
#     - 4. Building A Model of Machine Learning
#         - 4.1 Splitting the data into a 'train set' and a 'validation set' by using the 'train_test_split()' function.
#         - 4.2 Instructing a model on a 'train set' with the following two methods: 'logistic regression' and 'random forest'.
#             - 4.2.1 Logistic Regression
#             - 4.2.2 Random Forest
#         - 4.3 Evaluating the 'accuracy', 'precision' and 'recall' for both models by using 'validation set'.
#     - 5. User Cluster
#         - 5.1 Standardizing the data.
#         - 5.2 Using the 'linkage()' function to create a distance matrix based on a standardized feature matrix and graph of the dendrogram.
#         - 5.3 Instructing a clustering model with the 'K-means' algorithm and predict its customer clusters.
#         - 5.4 Looking at the feature values average for all the clusters.
#         - 5.5 Making a distribution feature graph for each clusters.
#         - 5.6 Calculating the churn rate for each clusters (by using the 'groupby()' method).
#     - 6. Presentation
#     - 7. General Conclusions and Recommendations

# %% [markdown]
# ##  Introduction

# %% [markdown]
#         The latest information regarding a fitness center franchise named, 'Model Fitness' is developing a customer engagement strategy based on analytical data.
#
#         One of the most common problems encountered by fitness center services and even other services is customer turnover or customer churn. How do we know when a customer has stopped using our service? We could indeed calculate the churn rate based on the number of people who delete accounts or do not renew their subscriptions. But sometimes, we could not know for sure whether a client has actually quit: they may have left us without our knowledge.
#
#         󠀰Churn indicators could vary from one field to another. If a user makes purchases from an online store on an irregular but regular basis, we could not say that the user has left our store. However, if for two weeks a user does not open an online shop channel which is updated daily, then we could worry: our followers may get bored and decide to leave us.
#
#         󠀰For fitness center businesses, it will be considered a customer to leave if they do not return for one month. In fact, it is not necessarily true. A customer may not visit the fitness center for a month because he or she is on vacation, for example to Bali, and will return to visit the fitness center after his or her vacation is over. However, cases like this are rare. Usually if a customer decides to join, then comes a few times and then disappears, the chances are that customer will not come back.

# %% [markdown]
# ### Goal

# %% [markdown]
#         From the explanation above, to reduce the churn rate, 'Model Fitness' has digitized a number of its customer profiles. Our task is to analyze the profiles of these customers and develop customer retention strategies (customer retention).
#
#         For that, we have to:
#         - Learn how to predict the churn probability (for the next month) for each customer
#         - Create user segmentation by selecting the most dominant group and describing its main features
#         - Analyze the factors that most influence churn
#         - Draw basic conclusions and provide recommendations on how to improve customer service
#             - Identify the target group
#             - Recommend steps to reduce churn
#             - Describe any other patterns we have encountered with customer interactions

# %% [markdown]
# ### Stages

# %% [markdown]
#     There are several stages to complete this project, namely:
#
#     Step 1. Downloading Database and Loading The Data
#     Step 2. Performing Explorative Data Analysis (EDA)
#     Step 3. Building a Model to Predict User Churn
#     Step 4. Creating A User Cluster
#     Step 5. Presenting My Project to The Viewers
#     Step 6. Formulating General Conclusions and Recommendations for Working with Customers
#
#
#     which is divided into the following detailed steps:
#
#     1. Data Overview and Preprocessing
#     2. Data Processing
#     3. Building Model of Machine Learning
#     4. User Cluster
#     5. Presentation
#     6. General Conclusions and Recommendations
#
#
#     With the following description:
#
#     1. Data Overview and Preprocessing (Step 1. Downloading Database and Loading The Data)
#     In this stage, we will load and read datasets from the following file path:
#
#     /datasets/gym_churn_us.csv
#
#     Here are the data descriptions of the file path above:
#
#     - 'Churn' — actual churn for the month
#     - 'gender'
#     - 'Near_Location' — whether the user lives or works near the gym location
#     - 'Partner' — whether the user is an employee of the partner company (this gym has a partner company and their employees are eligible for discounts; in this case, the gym stores information about the company their customer works for)
#     - Promo_friends — whether the user initially signed up via a "refer a friend" offer (they used a friend's promo code when paying for their first membership)
#     - 'Phone' — whether the user provided their phone number
#     - 'Age'
#     - 'Lifetime' — time (in months) since the customer's first visit to the fitness center
#     - 'Contract_period' — 1 month, 3 months, 6 months or 1 year
#     - 'Month_to_end_contract' — the remaining months before the contract expires
#     - 'Group_visits' — whether the user is taking part in group sessions
#     - 'Avg_class_frequency_total' — average frequency of visits per week over the customer's lifetime
#     - 'Avg_class_frequency_current_month' — average frequency of visits per week for the current month
#     - 'Avg_additional_charges_total' — the total amount of money spent to pay for other services at the gym: cafe, athletic goods, cosmetics, massage, etc.
#
#
#     2. Data Processing (Step 2. Performing Explorative Data Analysis (EDA))
#     In this stage, there are several things that need to be our focus, namely:
#
#     1. Taking a look at the dataset, are there any missing features?
#        - learning its average value and standard deviation (by using 'describe()' method).
#     2. Seeing the average feature value in two groups.
#        - namely for those who left (churn) and for those who stayed (by using 'groupby()' method).
#     3. Creating a histogram and feature distribution for those who left (churn) as well as those who stayed.
#     4. Creating a correlation matrix and display of the results.
#
#
#     3. Building Model of Machine Learning (Step 3. Building a Model to Predict User Churn)
#     In this stage, we will create a binary classification for customers, where the target feature will be users who will leave next month. During the process, we will do the following matters:
#
#     1. Splitting the data into a 'train set' and a 'validation set' by using the 'train_test_split()' function.
#     2. Instructing a model on a 'train set' with the following two methods:
#        - logistic regression
#        - random forest
#     3. Evaluating the 'accuracy', 'precision' and 'recall' for both models by using 'validation set'. We will use those metrics to compare the models. Which model gives the best results?
#
#     Next, we will indicate the 'random_state' parameter when dividing the data and specifying the algorithm.
#
#
#     4. User Cluster (Step 4. Creating A User Cluster)
#     In carrying out this stage, we will select the column that contains the churn data and define the cluster of objects (users) by doing the following:
#
#     1. Standardizing the data.
#     2. Using the 'linkage()' function to create a distance matrix based on a standardized feature matrix and graph of the dendrogram.
#        - For Note: The dendrogram creation may take some times.
#        - We will use the resulting graph to estimate the number of clusters we can choose from.
#     3. Instructing a clustering model with the 'K-means' algorithm and predict its customer clusters.
#        - Make it until the number of clusters is n = 5, so that it will be easier to compare the results we get with the results obtained by other students.
#        - However in real life, no one would ever give us such a hint.
#        - Therefore, going forward, we must make a decision based on the graph from the previous step.
#     4. Looking at the feature values average for all the clusters. Is there anything catches our attention?
#     5. Making a distribution feature graph for each clusters. Did we notice anything?
#     6. Calculating the churn rate for each clusters (by using the 'groupby()' method).
#        - Do the clusters differ in terms of churn rates?
#        - Which customer clusters are likely to leave, and which will remain loyal?
#
#
#     5. Presentation (Step 5. Presenting My Project to The Viewers)
#     In this stage, I will present for my Project Presentation related to 'Interaction and Retention Strategies Analysis through Digitizing Customer Profiles' analysis.
#
#
#     6. General Conclusions and Recommendations (Step 6. Formulating General Conclusions and Recommendations for Working with Customers)
#     In this stage, we will draw the conclusions and formulate recommendations regarding customer interaction and retention strategies.

# %% [markdown]
# [Back to Contents](#tableofcontents)

# %% [markdown]
# # Instructions for Completing the Project

# %% [markdown]
# ## Data Overview and Preprocessing
#     - Step 1. Downloading Database and Loading The Data

# %% [markdown]
# <div style="border:solid black 2px; padding: 20px">
#
#     First of all, we are going to load the required libraries or we called 'Loading Data' process, as follows:
#
# </div>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import spearmanr

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

from sklearn.cluster import KMeans
from scipy.cluster.hierarchy import dendrogram, linkage
from sklearn.metrics import accuracy_score, precision_score, recall_score

import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.precision', 15)
pd.set_option('display.max_columns', 300)

# %% [markdown]
#     Now, we will load the data files into DataFrames, as follows:

# %%
gym = pd.read_csv('/datasets/gym_churn_us.csv')

# %% [markdown]
#     These are the datas:

# %%
gym.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 14 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   gender                             4000 non-null   int64
#  1   Near_Location                      4000 non-null   int64
#  2   Partner                            4000 non-null   int64
#  3   Promo_friends                      4000 non-null   int64
#  4   Phone                              4000 non-null   int64
#  5   Contract_period                    4000 non-null   int64
#  6   Group_visits                       4000 non-null   int64
#  7   Age                                4000 non-null   int64
#  8   Avg_additional_charges_total       4000 non-null   float64
#  9   Month_to_end_contract              4000 non-null   float64
#  10  Lifetime                           4000 non-null   int64
# ...

# %% [markdown]
#     Findings:
#
#     - The datasets amounted 4000 rows and 14 columns.
#     - With data detailed, dtypes: float64(4), int64(10).
#     - The capitalization of the columns names title still contains a mixture of upper and lowercase letters.
#     - Datasets memory usage: 437.6 KB.
#     - In addition, there are some columns that define about customer profiles and membership data in the table above.
#     - Among them are consist of two columns of customer profiles and twelve columns of gym's membership information.
#     - Two columns describe customer profiles, those are 'Gender' and 'Age'.
#     - Twelve columns describe the information related to the gym's membership, those are 'Near_Location', 'Partner', 'Promo_friends', 'Phone', 'Contract_period', 'Group_visits', 'Avg_additional_charges_total', 'Month_to_end_contract', 'Lifetime', 'Avg_class_frequency_total', 'Avg_class_frequency_current_month', and 'Churn'.

# %% [markdown]
# [Back to Contents](#tableofcontents)

# %% [markdown]
# ### Data Overview Elaboration

# %% [markdown]
#     In this session, we will do the data overview elaboration by using some functions of 'columns', '.info()', '.head()', '.describe()', and '.isna().sum()' for checking the datas, as follows:

# %%
gym.columns
# Out:
# Index(['gender', 'Near_Location', 'Partner', 'Promo_friends', 'Phone',
#        'Contract_period', 'Group_visits', 'Age',
#        'Avg_additional_charges_total', 'Month_to_end_contract', 'Lifetime',
#        'Avg_class_frequency_total', 'Avg_class_frequency_current_month',
#        'Churn'],
#       dtype='object')

# %%
gym.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 14 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   gender                             4000 non-null   int64
#  1   Near_Location                      4000 non-null   int64
#  2   Partner                            4000 non-null   int64
#  3   Promo_friends                      4000 non-null   int64
#  4   Phone                              4000 non-null   int64
#  5   Contract_period                    4000 non-null   int64
#  6   Group_visits                       4000 non-null   int64
#  7   Age                                4000 non-null   int64
#  8   Avg_additional_charges_total       4000 non-null   float64
#  9   Month_to_end_contract              4000 non-null   float64
#  10  Lifetime                           4000 non-null   int64
# ...

# %%
gym.head()
# Out:
#    gender  Near_Location  Partner  Promo_friends  Phone  Contract_period  \
# 0       1              1        1              1      0                6
# 1       0              1        0              0      1               12
# 2       0              1        1              0      1                1
# 3       0              1        1              1      1               12
# 4       1              1        1              1      1                1
#
#    Group_visits  Age  Avg_additional_charges_total  Month_to_end_contract  \
# 0             1   29            14.227470422861144                    5.0
# 1             1   31           113.202937651058207                   12.0
# 2             0   28           129.448479332006144                    1.0
# 3             1   33            62.669863191238292                   12.0
# 4             0   26           198.362265439036833                    1.0
#
#    Lifetime  Avg_class_frequency_total  Avg_class_frequency_current_month  \
# ...

# %%
gym.describe()
# Out:
#                      gender         Near_Location              Partner  \
# count  4000.000000000000000  4000.000000000000000  4000.00000000000000
# mean      0.510250000000000     0.845250000000000     0.48675000000000
# std       0.499957425044087     0.361711412989101     0.49988689643489
# min       0.000000000000000     0.000000000000000     0.00000000000000
# 25%       0.000000000000000     1.000000000000000     0.00000000000000
# 50%       1.000000000000000     1.000000000000000     0.00000000000000
# 75%       1.000000000000000     1.000000000000000     1.00000000000000
# max       1.000000000000000     1.000000000000000     1.00000000000000
#
#               Promo_friends                 Phone      Contract_period  \
# count  4000.000000000000000  4000.000000000000000  4000.00000000000000
# mean      0.308500000000000     0.903500000000000     4.68125000000000
# std       0.461931916275352     0.295312634995689     4.54970585789327
# ...

# %%
gym.isna().sum()
# Out:
# gender                               0
# Near_Location                        0
# Partner                              0
# Promo_friends                        0
# Phone                                0
# Contract_period                      0
# Group_visits                         0
# Age                                  0
# Avg_additional_charges_total         0
# Month_to_end_contract                0
# Lifetime                             0
# Avg_class_frequency_total            0
# Avg_class_frequency_current_month    0
# Churn                                0
# dtype: int64

# %% [markdown]
#     Findings:
#
#     - In the results above, we find that these data are in the form of int64 and float64.
#     - In the result of '.head()' function, it displays that all of this data is in the form of numbers, consisting of integers and decimal numbers.
#     - No missing values were found in this dataset.

# %% [markdown]
# [Back to Contents](#tableofcontents)

# %% [markdown]
# ### Rectifying Columns Names

# %% [markdown]
#     As one of the findings above, there is case of the capitalization of the columns names title still contains a mixture of upper and lowercase letters. We will rectify them by changing all of columns names into lower case, as follows:

# %%
gym.columns = gym.columns.str.lower()

# %% [markdown]
#     Now, we look back into the table after rectifying the columns names:

# %%
gym.head()
# Out:
#    gender  near_location  partner  promo_friends  phone  contract_period  \
# 0       1              1        1              1      0                6
# 1       0              1        0              0      1               12
# 2       0              1        1              0      1                1
# 3       0              1        1              1      1               12
# 4       1              1        1              1      1                1
#
#    group_visits  age  avg_additional_charges_total  month_to_end_contract  \
# 0             1   29            14.227470422861144                    5.0
# 1             1   31           113.202937651058207                   12.0
# 2             0   28           129.448479332006144                    1.0
# 3             1   33            62.669863191238292                   12.0
# 4             0   26           198.362265439036833                    1.0
#
#    lifetime  avg_class_frequency_total  avg_class_frequency_current_month  \
# ...

# %% [markdown]
#     Findings:
#
#     - Now, we have managed to change the capitalization title and our data contains all in lowercase letters.

# %% [markdown]
# [Back to Contents](#tableofcontents)

# %% [markdown]
# ### Ensuring the Data Quality

# %% [markdown]
#     In this session, we will check the Data Quality of the target variable = churn column, as follows:

# %%
gym['churn'].value_counts()
# Out:
# 0    2939
# 1    1061
# Name: churn, dtype: int64

# %% [markdown]
#     And, we check the difference of percentage of the target variable = churn column, as follows:

# %%
gym['churn'].value_counts() / gym.shape[0] * 100
# Out:
# 0    73.474999999999994
# 1    26.524999999999999
# Name: churn, dtype: float64

# %% [markdown]
#     Next, we are going to ensure the others Data Quality by checking the names columns of 'gender', 'near_location', 'partner', 'promo_friends', 'phone', 'contract_period', 'group_visits', 'age', 'avg_additional_charges_total', 'month_to_end_contract', 'lifetime', 'avg_class_frequency_total', 'avg_class_frequency_current_month' from 'head()' function for reminding our data, as follows:

# %%
gym.head()
# Out:
#    gender  near_location  partner  promo_friends  phone  contract_period  \
# 0       1              1        1              1      0                6
# 1       0              1        0              0      1               12
# 2       0              1        1              0      1                1
# 3       0              1        1              1      1               12
# 4       1              1        1              1      1                1
#
#    group_visits  age  avg_additional_charges_total  month_to_end_contract  \
# 0             1   29            14.227470422861144                    5.0
# 1             1   31           113.202937651058207                   12.0
# 2             0   28           129.448479332006144                    1.0
# 3             1   33            62.669863191238292                   12.0
# 4             0   26           198.362265439036833                    1.0
#
#    lifetime  avg_class_frequency_total  avg_class_frequency_current_month  \
# ...

# %% [markdown]
#     First, we are going to ensure the data quality of the 'gender' column, as follows:

# %%
gym['gender'].value_counts()
# Out:
# 1    2041
# 0    1959
# Name: gender, dtype: int64

# %% [markdown]
#     Second, we are going to ensure the data quality of the 'near_location' column, as follows:

# %%
gym['near_location'].value_counts()
# Out:
# 1    3381
# 0     619
# Name: near_location, dtype: int64

# %% [markdown]
#     Third, we are going to ensure the data quality of the 'partner' column, as follows:

# %%
gym['partner'].value_counts()
# Out:
# 0    2053
# 1    1947
# Name: partner, dtype: int64

# %% [markdown]
#     Fourth, we are going to ensure the data quality of the 'promo_friends' column, as follows:

# %%
gym['promo_friends'].value_counts()
# Out:
# 0    2766
# 1    1234
# Name: promo_friends, dtype: int64

# %% [markdown]
#     Fifth, we are going to ensure the data quality of the 'phone' column, as follows:

# %%
gym['phone'].value_counts()
# Out:
# 1    3614
# 0     386
# Name: phone, dtype: int64

# %% [markdown]
#     Sixth, we are going to ensure the data quality of the 'contract_period' column, as follows:

# %%
gym['contract_period'].value_counts()
# Out:
# 1     2207
# 12     960
# 6      833
# Name: contract_period, dtype: int64

# %% [markdown]
#     Seventh, we are going to ensure the data quality of the 'group_visits' column, as follows:

# %%
gym['group_visits'].value_counts()
# Out:
# 0    2351
# 1    1649
# Name: group_visits, dtype: int64

# %% [markdown]
#     Eighth, we are going to ensure the data quality of the 'age' column, as follows:

# %%
gym['age'].value_counts()
# Out:
# 29    468
# 30    457
# 28    447
# 31    434
# 27    378
# 32    364
# 26    300
# 33    253
# 25    231
# 34    174
# 24    148
# 35     98
# 23     82
# 36     48
# 22     33
# 37     29
# 21     24
# 20     14
# 38     10
# 39      3
# 18      2
# 19      2
# 41      1
# Name: age, dtype: int64

# %% [markdown]
#     Ninth, we are going to ensure the data quality of the 'avg_additional_charges_total' column, as follows:

# %%
gym['avg_additional_charges_total'].value_counts()
# Out:
# 89.952761713196011     1
# 174.658454971316644    1
# 122.765562627157564    1
# 204.444526660235596    1
# 50.813165845559752     1
#                       ..
# 272.997180888981234    1
# 115.130268090511436    1
# 133.525137418048047    1
# 201.447650233383200    1
# 218.979321010159595    1
# Name: avg_additional_charges_total, Length: 4000, dtype: int64

# %% [markdown]
#     Tenth, we are going to ensure the data quality of the 'month_to_end_contract' column, as follows:

# %%
gym['month_to_end_contract'].value_counts()
# Out:
# 1.0     2207
# 6.0      645
# 12.0     524
# 11.0     181
# 5.0      130
# 10.0      82
# 9.0       73
# 4.0       58
# 8.0       38
# 7.0       25
# 3.0       23
# 2.0       14
# Name: month_to_end_contract, dtype: int64

# %% [markdown]
#     Eleventh, we are going to ensure the data quality of the 'lifetime' column, as follows:

# %%
gym['lifetime'].value_counts()
# Out:
# 1     843
# 2     610
# 3     490
# 0     487
# 4     383
# 5     273
# 6     220
# 7     167
# 8     111
# 9     100
# 10     76
# 12     53
# 11     48
# 13     28
# 15     24
# 14     24
# 16     15
# 17     11
# 19      7
# 18      7
# 20      7
# 21      5
# 26      2
# 24      2
# 22      2
# 23      2
# 27      1
# 29      1
# 31      1
# Name: lifetime, dtype: int64

# %% [markdown]
#     Twelfth, we are going to ensure the data quality of the 'avg_class_frequency_total' column, as follows:

# %%
gym['avg_class_frequency_total'].value_counts()
# Out:
# 0.000000000000000    88
# 0.827057777770946     1
# 2.770844775546217     1
# 1.472778971827282     1
# 3.735185167113578     1
#                      ..
# 2.602822665792981     1
# 1.295159122376891     1
# 1.138963153019333     1
# 2.262742806046202     1
# 0.992311766049633     1
# Name: avg_class_frequency_total, Length: 3913, dtype: int64

# %% [markdown]
#     Thirteenth, we are going to ensure the data quality of the 'avg_class_frequency_current_month' column, as follows:

# %%
gym['avg_class_frequency_current_month'].value_counts()
# Out:
# 0.000000000000000    181
# 0.379234579333639      1
# 0.054539990199985      1
# 1.877287962847488      1
# 1.058905878886095      1
#                     ...
# 3.115416943278582      1
# 3.429057951995418      1
# 3.233155739277696      1
# 2.564243198859297      1
# 1.454709622542359      1
# Name: avg_class_frequency_current_month, Length: 3820, dtype: int64

# %% [markdown]
#     Findings:
#
#     - We have checked the Data Quality of dataset columns.
#     - The data is already appropriate.

# %% [markdown]
# [Back to Contents](#tableofcontents)

# %% [markdown]
# ### Ensuring for Data Type, Array Form, Missing Values, Duplicate Data

# %% [markdown]
#     We will ensure the data, as follows:

# %%
gym.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 14 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   gender                             4000 non-null   int64
#  1   near_location                      4000 non-null   int64
#  2   partner                            4000 non-null   int64
#  3   promo_friends                      4000 non-null   int64
#  4   phone                              4000 non-null   int64
#  5   contract_period                    4000 non-null   int64
#  6   group_visits                       4000 non-null   int64
#  7   age                                4000 non-null   int64
#  8   avg_additional_charges_total       4000 non-null   float64
#  9   month_to_end_contract              4000 non-null   float64
#  10  lifetime                           4000 non-null   int64
# ...

# %% [markdown]
#     Now, we ensure the Data Type, as follows:

# %%
gym.dtypes
# Out:
# gender                                 int64
# near_location                          int64
# partner                                int64
# promo_friends                          int64
# phone                                  int64
# contract_period                        int64
# group_visits                           int64
# age                                    int64
# avg_additional_charges_total         float64
# month_to_end_contract                float64
# lifetime                               int64
# avg_class_frequency_total            float64
# avg_class_frequency_current_month    float64
# churn                                  int64
# dtype: object

# %% [markdown]
#     We ensure the Array Form, as follows:

# %%
gym.shape
# Out:
# (4000, 14)

# %% [markdown]
#     We ensure the Missing Values, as follows:

# %%
gym.isna().sum()
# Out:
# gender                               0
# near_location                        0
# partner                              0
# promo_friends                        0
# phone                                0
# contract_period                      0
# group_visits                         0
# age                                  0
# avg_additional_charges_total         0
# month_to_end_contract                0
# lifetime                             0
# avg_class_frequency_total            0
# avg_class_frequency_current_month    0
# churn                                0
# dtype: int64

# %% [markdown]
#     Finally, We ensure the Duplicate Data, as follows:

# %%
gym.duplicated().sum()
# Out:
# 0

# %% [markdown]
#     Findings:
#
#     - Now, we have ensured for Data Type, Array Form, Missing Values, Duplicate Data.
#     - The Data Type is already mentioned above, consist of int64 and float64.
#     - The Array Form is (4000, 14), that means 4000 rows and 14 columns as well.
#     - Exactly, there are no Missing Values in this dataset.
#     - And this dataset is clean from Duplicate Data.
#     - This dataset is ready to be analyzed and processed.

# %% [markdown]
# [Back to Contents](#tableofcontents)

# %% [markdown]
# ## Data Processing
#     - Step 2. Performing Explorative Data Analysis (EDA)

# %% [markdown]
# <div style="border:solid black 2px; padding: 20px">
#
#     In this step, there are several things that need to be our focus, namely:
#
#     1. Taking a look at the dataset, are there any missing features?
#        - learning its average value and standard deviation (by using 'describe()' method).
#     2. Seeing the average feature value in two groups.
#        - namely for those who left (churn) and for those who stayed (by using 'groupby()' method).
#     3. Creating a histogram and feature distribution for those who left (churn) as well as those who stayed.
#     4. Creating a correlation matrix and display of the results.
# </div>

# %% [markdown]
# ### Taking a look at the dataset, are there any missing features?
#     - learning its average value and standard deviation (by using 'describe()' method).

# %% [markdown]
#     In this session, we are going to study about the average that we called 'mean values' and standard deviation, as follows:

# %%
gym.isna().sum()
# Out:
# gender                               0
# near_location                        0
# partner                              0
# promo_friends                        0
# phone                                0
# contract_period                      0
# group_visits                         0
# age                                  0
# avg_additional_charges_total         0
# month_to_end_contract                0
# lifetime                             0
# avg_class_frequency_total            0
# avg_class_frequency_current_month    0
# churn                                0
# dtype: int64

# %% [markdown]
#     We look at the mean values and standard deviation of the data, as follows:

# %%
gym.describe()
# Out:
#                      gender         near_location              partner  \
# count  4000.000000000000000  4000.000000000000000  4000.00000000000000
# mean      0.510250000000000     0.845250000000000     0.48675000000000
# std       0.499957425044087     0.361711412989101     0.49988689643489
# min       0.000000000000000     0.000000000000000     0.00000000000000
# 25%       0.000000000000000     1.000000000000000     0.00000000000000
# 50%       1.000000000000000     1.000000000000000     0.00000000000000
# 75%       1.000000000000000     1.000000000000000     1.00000000000000
# max       1.000000000000000     1.000000000000000     1.00000000000000
#
#               promo_friends                 phone      contract_period  \
# count  4000.000000000000000  4000.000000000000000  4000.00000000000000
# mean      0.308500000000000     0.903500000000000     4.68125000000000
# std       0.461931916275352     0.295312634995689     4.54970585789327
# ...

# %% [markdown]
#     We are going to plot the feature of 'avg_additional_charges_total', as follows:

# %%
sns.histplot(gym['avg_additional_charges_total'])
plt.title('The distribution of avg_additional_charges_total');

# %% [markdown]
#     We make plot the feature of 'age', as follows:

# %%
sns.histplot(gym['age'])
plt.title('The distribution of age');

# %% [markdown]
#     Findings at this moment:
#
#     - There is no missing values from our work results.
#     - The data distribution of each features mostly are normal, since many features are binary (1/0).
#     - The feature of 'avg_additional_charges_total' has a positive skew because the distance between the mean values and standard deviation, respectively 146.943 vs. 96.35 (first plot above).
#     - Subsequently, the feature of 'age' has a normal distribution which the mean values and the standard deviation are 29.184 vs. 3.2 5 (second plot above).

# %% [markdown]
# [Back to Contents](#tableofcontents)

# %% [markdown]
# ### Seeing the average feature value in two groups.
#     - namely for those who left (churn) and for those who stayed (by using 'groupby()' method).

# %% [markdown]
#     We will make grouping of churn column to see the mean values, as follows:

# %%
gym.groupby('churn').mean()
# Out:
#                   gender      near_location            partner  \
# churn
# 0      0.510037427696495  0.873086083701939  0.534195304525349
# 1      0.510838831291235  0.768143261074458  0.355325164938737
#
#            promo_friends              phone    contract_period  \
# churn
# 0      0.353521605988431  0.903708744470908  5.747192922762845
# 1      0.183788878416588  0.902921771913289  1.728557964184731
#
#             group_visits                 age  avg_additional_charges_total  \
# churn
# 0      0.464103436543042  29.976522626743790           158.445714801611899
# 1      0.268614514608860  26.989632422243165           115.082898619287263
#
#        month_to_end_contract           lifetime  avg_class_frequency_total  \
# churn
# 0          5.283089486219803  4.711806736985369          2.024875642518554
# 1          1.662582469368520  0.990574929311970          1.474994662372977
#
#        avg_class_frequency_current_month
# churn
# 0                      2.027881733095179
# ...

# %% [markdown]
#     Findings at this moment:
#
#     - The mean feature values such as 'contract_period', 'month_to_end_contract', 'lifetime', and 'avg_additional_charges_total' for those who stayed are high than those who left (5.74 vs. 1.72, 5.28 vs. 1.66, 4.71 vs. 0.90, and 158.44 vs. 115.08 respectively).
#     - That is to say, the customer with the most remaining number of months until the contract expires, will have a higher probability to stay than those who have one month left until the contract expires.

# %% [markdown]
# [Back to Contents](#tableofcontents)

# %% [markdown]
# ### Creating a histogram and feature distribution for those who left (churn) as well as those who stayed.

# %% [markdown]
#     First, we define a formula for visualization, as follows:

# %%
def feat_hist (x, group_col, key_cols):
    x_new = x.copy ()
    x_new[key_cols] = gym [key_cols]
    for c in key_cols:
        for cl in x[group_col].unique():
            sns.distplot(x_new[x_new [group_col]==cl][c],
                         label='{} = {}'.format(group_col, str(cl)), bins = 10)
        plt.title(c)
        plt.legend()
        plt.show()

# %% [markdown]
#     Now, we visualize the distribution of churn and stayed, as follows:

# %%
feat_hist(gym, 'churn', gym.columns)

# %% [markdown]
#     Findings at this moment:
#
#     - In this case, there are vocabularies use, those are 'churn' and 'stayed'. They seems into 'churn' = 'churn' and 'stayed' = 'not churn' for called them.
#     - The features of 'gender', 'near_location', 'partner', 'promo_friends', 'phone', 'group_visits', 'age', 'avg_class_frequency_current_month' are not take affect of the churn customer, because the curve pictures are same between churn and not churn.
#     - Furthermore, the curve of 'contract_period', 'month_to_end_contract', 'lifetime', 'avg_additional_charges_total' and 'avg_class_frequency_total' features show a significant difference between churn and not churn. The lowest the number, the highest customers will churn.

# %% [markdown]
# [Back to Contents](#tableofcontents)

# %% [markdown]
# ### Creating a correlation matrix and display of the results.

# %% [markdown]
#     Now, we are going to make the correlation matrix, as follows:

# %%
plt.figure(figsize=(13,13))
sns.heatmap(gym.corr(), annot=True)
plt.title('The Correlation between Churn and Not Churn with Features')
plt.show()

# %% [markdown]
#     This is the correlation 'churn' with the features, as follows:

# %%
gym.corr()['churn']
# Out:
# gender                               0.000707733985153
# near_location                       -0.128097990299810
# partner                             -0.157985736985098
# promo_friends                       -0.162233077833515
# phone                               -0.001176601362480
# contract_period                     -0.389984211586078
# group_visits                        -0.175324655498149
# age                                 -0.404735252823589
# avg_additional_charges_total        -0.198697451068203
# month_to_end_contract               -0.381392983695714
# lifetime                            -0.438219968447980
# avg_class_frequency_total           -0.249715111332895
# avg_class_frequency_current_month   -0.412348390707265
# churn                                1.000000000000000
# Name: churn, dtype: float64

# %% [markdown]
#     Findings at this moment:
#
#     - From the correlation matrix above, we can say that all features have a negative relationship with churn. Then, we can assume that the lowest of the lifetime value since the customer first came to the gym, the highest possibility of customers will churn.

# %% [markdown]
# [Back to Contents](#tableofcontents)

# %% [markdown]
# ## Building A Model of Machine Learning
#     - Step 3. Building a Model to Predict User Churn

# %% [markdown]
# <div style="border:solid black 2px; padding: 20px">
#
#     In this session, we will create a binary classification for customers, where the target feature will be users who will leave next month. During the process, we will do the following matters:
#
#     1. Splitting the data into a 'train set' and a 'validation set' by using the 'train_test_split()' function.
#     2. Instructing a model on a 'train set' with the following two methods:
#        - logistic regression
#        - random forest
#     3. Evaluating the 'accuracy', 'precision' and 'recall' for both models by using 'validation set'. We will use those metrics to compare the models. Which model gives the best results?
#
#     Next, we will indicate the 'random_state' parameter when dividing the data and specifying the algorithm.
#
# </div>

# %% [markdown]
# ### Splitting the data into a 'train set' and a 'validation set' by using the 'train_test_split()' function.

# %% [markdown]
#     First, we will split the data into train and validation sets, as follows:

# %%
X = gym.drop(columns = ['churn'])
y = gym['churn']

X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2, random_state=2022)

# %% [markdown]
#     Then, we look at the shape of train and validation sets, as follows:

# %%
X_train.shape, X_val.shape
# Out:
# ((3200, 13), (800, 13))

# %% [markdown]
#     We look at the head data of train, as follows:

# %%
X_train.head()
# Out:
#       gender  near_location  partner  promo_friends  phone  contract_period  \
# 3167       1              0        1              0      1                6
# 2001       1              1        1              1      1                1
# 3933       1              1        0              0      1                6
# 1952       0              1        0              0      1                6
# 1534       0              1        1              1      1               12
#
#       group_visits  age  avg_additional_charges_total  month_to_end_contract  \
# 3167             0   30           297.189815590227909                    5.0
# 2001             0   27           265.053085156232896                    1.0
# 3933             1   28            49.939368538110131                    6.0
# 1952             0   31            46.971990251828288                    4.0
# 1534             1   26            42.542070469049492                    7.0
#
# ...

# %% [markdown]
#     Findings at this moment:
#
#     - The target value (X) is 'churn' and the rest are the features (Y).
#     - We use 'train_test_split' from 'sklearn.model_selection' to split the data into 'train' and 'validation sets'.
#     - We split the data of 'train' and 'validation sets' with proportion of 80:20.
#     - We fill the 'random_state' = (by using) 2022, so the results will be selected randomly fair and equally.
#     - The results of 'train sets' has 3200 observations and 'validation sets' has 800 observations.

# %% [markdown]
# [Back to Contents](#tableofcontents)

# %% [markdown]
# ### Instructing a model on a 'train set' with the following two methods: 'logistic regression' and 'random forest'.

# %% [markdown]
#     The two methods we are going to use are:
#     - logistic regression
#     - random forest

# %% [markdown]
# #### Logistic Regression

# %% [markdown]
#     We will instruct the model on the 'train set' with 'Logistic Regression', as follows:

# %%
lr_model = LogisticRegression(random_state=2022)

lr_model.fit(X_train, y_train)

y_proba_lr = lr_model.predict_proba(X_val)
y_pred_lr = lr_model.predict(X_val)

print('Accuracy Score for Logistic Regression is: {:.2f}'.format(accuracy_score(y_val, y_pred_lr)))
print('Precision Score for Logistic Regression is: {:.2f}'.format(precision_score(y_val, y_pred_lr)))
print('Recall Score for Logistic Regression is: {:.2f}'.format(recall_score(y_val, y_pred_lr)))
# Out:
# Accuracy Score for Logistic Regression is: 0.93
# Precision Score for Logistic Regression is: 0.90
# Recall Score for Logistic Regression is: 0.84

# %% [markdown]
# #### Random Forest

# %% [markdown]
#     Now, we will instruct the model on the 'train set' with Random Forest, as follows:

# %%
rf_model = RandomForestClassifier(n_estimators=100, random_state=2022)

rf_model.fit(X_train, y_train)

y_proba_rf = rf_model.predict_proba(X_val)
y_pred_rf = rf_model.predict(X_val)

print('Accuracy Score for Random Forest is: {:.2f}'.format(accuracy_score(y_val, y_pred_lr)))
print('Precision Score for Random Forest is: {:.2f}'.format(precision_score(y_val, y_pred_lr)))
print('Recall Score for Random Forest is: {:.2f}'.format(recall_score(y_val, y_pred_lr)))
# Out:
# Accuracy Score for Random Forest is: 0.93
# Precision Score for Random Forest is: 0.90
# Recall Score for Random Forest is: 0.84

# %% [markdown]
#     Findings at this moment:
#
#     - We have instructed the model on a 'train set' with 'logistic regression' and 'random forest' methods.

# %% [markdown]
# [Back to Contents](#tableofcontents)

# %% [markdown]
# ### Evaluating the 'accuracy', 'precision' and 'recall' for both models by using 'validation set'.
#     - We will use those metrics to compare the models. Which model gives the best results?

# %% [markdown]
#     From Logistic Regression method, we have:
#
#     - Accuracy Score for Logistic Regression is: 0.93
#     - Precision Score for Logistic Regression is: 0.90
#     - Recall Score for Logistic Regression is: 0.84

# %% [markdown]
#     From Random Forest method, we have:
#
#     - Accuracy Score for Random Forest is: 0.93
#     - Precision Score for Random Forest is: 0.90
#     - Recall Score for Random Forest is: 0.84

# %% [markdown]
#     Findings at this moment:
#
#     - We indicate the 'random_state' parameter when splitting data and defining the algorithm = 2022.
#     - We have evaluated the accuracy, precision, and recall for both models by using the validation data.
#     - Both of the two models have given the same results which are:
#         - Accuracy score: 0.93
#         - Precision score: 0.90
#         - Recall score: 0.84

# %% [markdown]
# [Back to Contents](#tableofcontents)

# %% [markdown]
# ## User Cluster
#     - Step 4. Creating A User Cluster

# %% [markdown]
# <div style="border:solid black 2px; padding: 20px">
#
#     In carrying out this step, we will select the column that contains the churn data and define the cluster of objects (users) by doing the following:
#
#     1. Standardizing the data.
#     2. Using the 'linkage()' function to create a distance matrix based on a standardized feature matrix and graph of the dendrogram.
#        - For Note: The dendrogram creation may take some times.
#        - We will use the resulting graph to estimate the number of clusters we can choose from.
#     3. Instructing a clustering model with the 'K-means' algorithm and predict its customer clusters.
#        - Make it until the number of clusters is n = 5, so that it will be easier to compare the results we get with the results obtained by other students.
#        - However in real life, no one would ever give us such a hint.
#        - Therefore, going forward, we must make a decision based on the graph from the previous step.
#     4. Looking at the feature values average for all the clusters. Is there anything catches our attention?
#     5. Making a distribution feature graph for each clusters. Did we notice anything?
#     6. Calculating the churn rate for each clusters (by using the 'groupby()' method).
#        - Do the clusters differ in terms of churn rates?
#        - Which customer clusters are likely to leave, and which will remain loyal?
#
# </div>

# %% [markdown]
# ### Standardizing the data.

# %% [markdown]
#     Firstly, we have to standardize the data because the clusters method is unsupervised learning without "right answers".

# %% [markdown]
#     Here is the standardize the data, as follows:

# %%
sc = StandardScaler()
x_sc = sc.fit_transform(gym.drop(columns='churn'))

# %% [markdown]
# [Back to Contents](#tableofcontents)

# %% [markdown]
# ### Using the 'linkage()' function to create a distance matrix based on a standardized feature matrix and graph of the dendrogram.
#     - For Note: The dendrogram creation may take some times.
#     - We will use the resulting graph to estimate the number of clusters we can choose from.

# %% [markdown]
#     Secondly, we build a matrix of distances based on the standardized feature matrix using linkage(), as follows:

# %%
linked = linkage(x_sc, method='ward')

# %% [markdown]
#     Here is the Visualization of the 'Hierarchical Clustering Form GYM', as follows:

# %%
plt.figure(figsize=(15, 10))
dendrogram(linked, orientation='top')
plt.title('Hierarchical Clustering Form GYM')
plt.show()

# %% [markdown]
#     Findings at this moment:
#
#     - By creating user clusters with the 'linkage()' function results that the data is being split into four clusters, with the violet cluster as the biggest cluster and the green is smallest cluster.

# %% [markdown]
# [Back to Contents](#tableofcontents)

# %% [markdown]
# ### Instructing a clustering model with the 'K-means' algorithm and predict its customer clusters.
#     - Make it until the number of clusters is n = 5, so that it will be easier to compare the results we get with the results obtained by other students.
#     - However in real life, no one would ever give us such a hint.
#     - Therefore, going forward, we must make a decision based on the graph from the previous step.

# %% [markdown]
#     We will instruct a clustering model with K-means algorithm, as follows:

# %%
km = KMeans(n_clusters = 5)
labels = km.fit_predict(gym.drop(columns=['churn']))

# %% [markdown]
#     Findings at this moment:
#
#     - We have instructed a clustering model with K-means algorithm.

# %% [markdown]
# [Back to Contents](#tableofcontents)

# %% [markdown]
# ### Looking at the feature values average for all the clusters.
#     - Is there anything catches our attention?

# %% [markdown]
#     Now, we will create cluster labels and calculate by using formula of 'count()', as follows:

# %%
gym['cluster_km'] = labels
gym.groupby(['cluster_km']).count()
# Out:
#             gender  near_location  partner  promo_friends  phone  \
# cluster_km
# 0             1027           1027     1027           1027   1027
# 1              271            271      271            271    271
# 2             1034           1034     1034           1034   1034
# 3              706            706      706            706    706
# 4              962            962      962            962    962
#
#             contract_period  group_visits   age  avg_additional_charges_total  \
# cluster_km
# 0                      1027          1027  1027                          1027
# 1                       271           271   271                           271
# 2                      1034          1034  1034                          1034
# 3                       706           706   706                           706
# 4                       962           962   962                           962
#
#             month_to_end_contract  lifetime  avg_class_frequency_total  \
# ...

# %% [markdown]
#     Then, we calculate each cluster using formula of 'sum()', as follows:

# %%
gym.groupby(['cluster_km']).sum()
# Out:
#             gender  near_location  partner  promo_friends  phone  \
# cluster_km
# 0              529            862      463            288    922
# 1              127            232      140             90    251
# 2              525            853      506            303    939
# 3              368            622      361            245    634
# 4              492            812      477            308    868
#
#             contract_period  group_visits    age  \
# cluster_km
# 0                      4413           418  29763
# 1                      1578           117   8088
# 2                      4346           401  29885
# 3                      3813           306  20717
# 4                      4575           407  28284
#
#             avg_additional_charges_total  month_to_end_contract  lifetime  \
# cluster_km
# 0                 108863.136035107148928                 4101.0      3645
# 1                  96606.611189195973566                 1459.0      1198
# ...

# %% [markdown]
#     We will calculate mean values for each clusters, as follows:

# %%
gym.groupby(['cluster_km']).mean()
# Out:
#                        gender      near_location            partner  \
# cluster_km
# 0           0.515092502434275  0.839337877312561  0.450827653359299
# 1           0.468634686346863  0.856088560885609  0.516605166051661
# 2           0.507736943907157  0.824951644100580  0.489361702127660
# 3           0.521246458923513  0.881019830028329  0.511331444759207
# 4           0.511434511434511  0.844074844074844  0.495841995841996
#
#                 promo_friends              phone    contract_period  \
# cluster_km
# 0           0.280428432327167  0.897760467380721  4.296981499513145
# 1           0.332103321033210  0.926199261992620  5.822878228782288
# 2           0.293036750483559  0.908123791102515  4.203094777562863
# 3           0.347025495750708  0.898016997167139  5.400849858356940
# 4           0.320166320166320  0.902286902286902  4.755717255717256
#
#                  group_visits                 age  \
# cluster_km
# 0           0.407010710808179  28.980525803310613
# ...

# %% [markdown]
#     Findings at this moment:
#
#     - Creating user clusters with the K-means algorithm results that the data is being split into five clusters.
#     - Among other features, the feature value of 'avg_additional_charges_total' has a big different value in each clusters. Therefore, we can assume that cluster 2 is the most spending group with an additional average charge of $356.481.
# - While cluster 1 is the most economical spending with the additional average charge of $35.53.

# %% [markdown]
# [Back to Contents](#tableofcontents)

# %% [markdown]
# ### Making a distribution feature graph for each clusters.
#     - Did we notice anything?

# %% [markdown]
#     In this session, we will make plot graph visualization of the churn and stayed distribution by using K-means algorithm, as follows:

# %%
feat_hist(gym, 'cluster_km', gym.columns)

# %% [markdown]
#     Findings at this moment:
#
#     - Supported by the visualization above, we can see that each clusters has a different feature value of 'avg_additional_charges_total'.
#     - Each curve is in a different cluster.
#     - While for other feature values, it has a stacked curve in all clusters.

# %% [markdown]
# [Back to Contents](#tableofcontents)

# %% [markdown]
# ### Calculating the churn rate for each clusters (by using the 'groupby()' method).
#     - Do the clusters differ in terms of churn rates?
#     - Which customer clusters are likely to leave, and which will remain loyal?

# %% [markdown]
#     We are going to make grouping churn rate by cluster, as follows:

# %%
gym.groupby(['cluster_km']).mean()['churn']
# Out:
# cluster_km
# 0    0.333982473222980
# 1    0.044280442804428
# 2    0.350096711798839
# 3    0.178470254957507
# 4    0.226611226611227
# Name: churn, dtype: float64

# %% [markdown]
#     Findings at this moment:
#
#     - Cluster 2 is the royal cluster with a churn rate of 0.044 only.
#     - While Cluster 1 is the customers tend to leave (churn rate of 0.351).

# %% [markdown]
# [Back to Contents](#tableofcontents)

# %% [markdown]
# ## Presentation
#     - Step 5. Presenting My Project to The Viewers

# %% [markdown]
# <div style="border:solid black 2px; padding: 20px">
#
#     This is my presentation of 'Interaction and Retention Strategies Analysis through Digitizing Customer Profiles' project by me, awrb.
#
# </div>

# %% [markdown]
# Presentation Link: https://drive.google.com/file/d/1U7nmn9yu_QsLhoJKupXsRVdCcAsc3Ele/view?usp=sharing

# %% [markdown]
# [Back to Contents](#tableofcontents)

# %% [markdown]
# ## General Conclusions and Recommendations
#     - Step 6. Formulating General Conclusions and Recommendations for Working with Customers

# %% [markdown]
# <div style="border:solid black 2px; padding: 20px">
#
#     󠀰Drawing conclusions and formulating recommendations regarding customer interaction and retention strategies.
#
# </div>

# %% [markdown]
#     Here are the General Conclusions from each steps and the Recommendations are provided, as follows:

# %% [markdown]
# # Step 1. Data Overview and Preprocessing

# %% [markdown]
# <div style="border:solid black 2px; padding: 20px">
#
#     1. Downloading Database and Loading The Data
#
#     Findings:
#     - The datasets amounted 4000 rows and 14 columns.
#     - With data detailed, dtypes: float64(4), int64(10).
#     - The capitalization of the names columns title still contains a mixture of upper and lowercase letters.
#     - Datasets memory usage: 437.6 KB.
#     - In addition, there are some columns that define about customer profiles and membership data in the table above.
#     - Among them are consist of two columns of customer profiles and twelve columns of gym's membership information.
#     - Two columns describe customer profiles, those are 'Gender' and 'Age'.
#     - Twelve columns describe the information related to the gym's membership, those are 'Near_Location', 'Partner', 'Promo_friends', 'Phone', 'Contract_period', 'Group_visits', 'Avg_additional_charges_total', 'Month_to_end_contract', 'Lifetime', 'Avg_class_frequency_total', 'Avg_class_frequency_current_month', and 'Churn'.
#
#
#     2. Data Overview Elaboration
#     Findings:
#     - In the results above, we find that these data are in the form of int64 and float64.
#     - In the result of '.head()' function, it displays that all of this data is in the form of numbers, consisting of integers and decimal numbers.
#     - No missing values were found in this dataset.
#
#
#     3. Rectifying Names Columns
#     Findings:
#     - Now, we have managed to change the capitalization title and our data contains all in lowercase letters.
#
#
#     4. Ensuring the Data Quality
#     Findings:
#     - We have checked the Data Quality of dataset columns.
#     - The data is already appropriate.
#
#
#     5. Ensuring for Data Type, Array Form, Missing Values, Duplicate Data
#     Findings:
#     - Now, we have ensured for Data Type, Array Form, Missing Values, Duplicate Data.
#     - The Data Type is already mentioned above, consist of int64 and float64.
#     - The Array Form is (4000, 14), that means 4000 rows and 14 columns as well.
#     - Exactly, there are no Missing Values in this dataset.
#     - And this dataset is clean from Duplicate Data.
#     - This dataset is ready to be analyzed and processed.
#
# </div>

# %% [markdown]
# # Step 2. Data Processing

# %% [markdown]
# <div style="border:solid black 2px; padding: 20px">
#
#     Step 2. Performing Explorative Data Analysis (EDA)
#
#     1. Taking a look at the dataset, are there any missing features?
#     Findings at this moment:
#     - There is no missing values from our work results.
#     - The data distribution of each features mostly are normal, since many features are binary (1/0).
#     - The feature of 'avg_additional_charges_total' has a positive skew because the distance between the mean values and standard deviation, respectively 146.943 vs. 96.35 (first plot above).
#     - Subsequently, the feature of 'age' has a normal distribution which the mean values and the standard deviation are 29.184 vs. 3.2 5 (second plot above).
#
#
#     2. Seeing the average feature value in two groups.
#     Findings at this moment:
#     - The mean feature values such as 'contract_period', 'month_to_end_contract', 'lifetime', and 'avg_additional_charges_total' for those who stayed are high than those who left (5.74 vs. 1.72, 5.28 vs. 1.66, 4.71 vs. 0.90, and 158.44 vs. 115.08 respectively).
#     - That is to say, the customer with the most remaining number of months until the contract expires, will have a higher probability to stay than those who have one month left until the contract expires.
#
#
#     3. Creating a histogram and feature distribution for those who left (churn) as well as those who stayed.
#     Findings at this moment:
#     - In this case, there are vocabularies use, those are 'churn' and 'stayed'. They seems into 'churn' = 'churn' and 'stayed' = 'not churn' for called them.
#     - The features of 'gender', 'near_location', 'partner', 'promo_friends', 'phone', 'group_visits', 'age', 'avg_class_frequency_current_month' are not take affect of the churn customer, because the curve pictures are same between churn and not churn.
#     - Furthermore, the curve of 'contract_period', 'month_to_end_contract', 'lifetime', 'avg_additional_charges_total' and 'avg_class_frequency_total' features show a significant difference between churn and not churn. The lowest the number, the highest customers will churn.
#
#
#     4. Creating a correlation matrix and display of the results.
#     Findings at this moment:
#     - From the correlation matrix above, we can say that all features have a negative relationship with churn. Then, we can assume that the lowest of the lifetime value since the customer first came to the gym, the highest possibility of customers will churn.
#
# </div>

# %% [markdown]
# # Step 3. Building Model of Machine Learning

# %% [markdown]
# <div style="border:solid black 2px; padding: 20px">
#
#     Step 3. Building a Model to Predict User Churn
#
#     1. Spliting the data into a 'train set' and a 'validation set' by using the 'train_test_split()' function.
#     Findings at this moment:
#     - The target value (X) is 'churn' and the rest are the features (Y).
#     - We use 'train_test_split' from 'sklearn.model_selection' to split the data into 'train' and 'validation sets'.
#     - We split the data of 'train' and 'validation sets' with proportion of 80:20.
#     - We fill the 'random_state' = (by using) 2022, so the results will be selected randomly fair and equally.
#     - The results of 'train sets' has 3200 observations and 'validation sets' has 800 observations.
#
#
#     2. Instructing a model on a 'train set' with the following two methods: 'logistic regression' and 'random forest'.
#     Findings at this moment:
#     - We have instructed the model on a 'train set' with 'logistic regression' and 'random forest' methods.
#
#
#     3. Evaluating the 'accuracy', 'precision' and 'recall' for both models by using 'validation set'.
#     Findings at this moment:
#     - We indicate the 'random_state' parameter when splitting data and defining the algorithm = 2022.
#     - We have evaluated the accuracy, precision, and recall for both models by using the validation data.
#     - Both of the two models have given the same results which are:
#         - Accuracy score: 0.93
#         - Precision score: 0.90
#         - Recall score: 0.84
#
# </div>

# %% [markdown]
# # Step 4. User Cluster

# %% [markdown]
# <div style="border:solid black 2px; padding: 20px">
#
#     Step 4. Creating A User Cluster
#
#     1. Using the 'linkage()' function to create a distance matrix based on a standardized feature matrix and graph of the dendrogram.
#     Findings at this moment:
#     - By creating user clusters with the 'linkage()' function results that the data is being split into four clusters, with the violet cluster as the biggest cluster and the green is smallest cluster.
#
#
#     2. Instructing a clustering model with the 'K-means' algorithm and predict its customer clusters.
#     Findings at this moment:
#     - We have instructed a clustering model with K-means algorithm.
#
#
#     3. Looking at the feature values average for all the clusters.
#     Findings at this moment:
#     - Creating user clusters with the K-means algorithm results that the data is being split into five clusters.
#     - Among other features, the feature value of 'avg_additional_charges_total' has a big different value in each clusters. Therefore, we can assume that cluster 2 is the most spending group with an additional average charge of $356.481.
#     - While cluster 1 is the most economical spending with the additional average charge of $35.53.
#
#
#     4. Making a distribution feature graph for each clusters.
#     Findings at this moment:
#     - Supported by the visualization above, we can see that each clusters has a different feature value of 'avg_additional_charges_total'.
#     - Each curve is in a different cluster.
#     - While for other feature values, it has a stacked curve in all clusters.
#
#
#     5. Calculating the churn rate for each clusters (by using the 'groupby()' method).
#     Findings at this moment:
#     - Cluster 2 is the royal cluster with a churn rate of 0.044 only.
#     - While Cluster 1 is the customers tend to leave (churn rate of 0.351).
#
# </div>

# %% [markdown]
# # Recommendations:

# %% [markdown]
# <div style="border:solid black 2px; padding: 20px">
#
#     - We could predict that the probability of churn (for the upcoming month) for each customer is customer with the lowest month_to_end_contract left (1 month). It is the factor that impact churn most. To reduce this probability happen, we could offer them vouchers/discounts for membership then they might still stay for the upcoming month.
#     - The cluster with the lowest 'avg_additional_charges_total' (Cluster 1), we can offer them meal vouchers, so they have the potential to come to the cafe. Because based on the churn rate, we know that the customers with the highest 'avg_additional_charges_total' (Cluster 2) is the royal cluster with the lowest churn rate.
#
# </div>

# %% [markdown]
# [Back to Contents](#tableofcontents)
